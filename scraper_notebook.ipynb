# %%
import os
import warnings
from dataclasses import dataclass, field
from typing import Dict, List, Type 

import pandas as pd
import requests
from allocine_scraper_class import AllocineScraper
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

warnings.filterwarnings('ignore')

# %%
# factory movie types
movie_types_dict= {
    "Action" : "13025",
    "Comédie" : "13005",
    "Aventure" : "13001",
    "Animation" : "13026",
    "Science-Fiction" : "13021",
    "Thriller" : "13023",
    "Romance" : "13024"
}

MAX_PAGES = 500
# dataclass instance
scraper = AllocineScraper(genres_dict=movie_types_dict, MAX_PAGES=MAX_PAGES)

# hrefs/links collection
scraper.collect_review_links()

# hrefs/links scraping getting infos
max_reviews = 7500
scraper.scrape_reviews(max_reviews=max_reviews)

# export to parquet file
PATH_EXPORT_DATA = "./data/"
FILE_NAME = "critics.parquet"
scraper.export_to_parquet(filepath=PATH_EXPORT_DATA+FILE_NAME)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\MourZ\Documents\nlp_project\scraper\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\MourZ\Documents\nlp_project\scraper\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...
